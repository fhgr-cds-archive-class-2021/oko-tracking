# %%
import pandas as pd

# %%
df = pd.read_csv('event_data.tsv', sep='\t')

# %%
df.head()
# Out:
#     Recording Participant   Timeline        TOI  Interval  Media Event_type  \
# 0  Recording1           M  Timeline1  Task1 (1)         1  Task1   Fixation
# 1  Recording1           M  Timeline1  Task1 (1)         1  Task1    Saccade
# 2  Recording1           M  Timeline1  Task1 (1)         1  Task1   Fixation
# 3  Recording1           M  Timeline1  Task1 (1)         1  Task1    Saccade
# 4  Recording1           M  Timeline1  Task1 (1)         1  Task1   Fixation
#
#   Validity  EventIndex  Start  ...  Saccade_direction  Average_velocity  \
# 0  Partial           1      0  ...                NaN               NaN
# 1    Whole           1    237  ...             160.64            154.19
# 2    Whole           2    287  ...                NaN               NaN
# 3    Whole           2    537  ...             160.06            387.62
# 4    Whole           3    553  ...                NaN               NaN
#
# ...
